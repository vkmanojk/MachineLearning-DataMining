# %%
# !pip install fuzzy-c-means
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.3 is available.
# You should consider upgrading via the 'c:\users\sanjaybharadwaj\appdata\local\programs\python\python36\python.exe -m pip install --upgrade pip' command.

# %%
from fcmeans import FCM
import pandas as pd
import matplotlib.pyplot as plt
from seaborn import scatterplot as scatter
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
df=pd.read_csv('SPECTF_New.csv')
df.head()
# Out:
#    Attr_1  Attr_2  Attr_3  Attr_4  Attr_5  Attr_6  Attr_7  Attr_8  Attr_9  \
# 0      57      69      68      75      69      74      73      71      57
# 1      76      59      82      76      80      56      74      67      67
# 2      65      62      67      68      65      67      71      71      64
# 3      70      54      66      66      76      46      74      58      68
# 4      64      64      70      75      70      71      74      71      59
#
#    Attr_10  ...  Attr_36  Attr_37  Attr_38  Attr_39  Attr_40  Attr_41  \
# 0       61  ...       58       69       67       79       77       72
# 1       58  ...       66       73       61       71       49       53
# 2       56  ...       63       74       63       77       79       68
# 3       52  ...       55       65       56       65       44       73
# 4       60  ...       66       61       56       64       65       71
#
#    Attr_42  Attr_43  Attr_44  Class
# 0       70       61       65    Yes
# ...

# %%
df.shape
# Out:
# (110, 45)

# %%
df.describe()
# Out:
#            Attr_1      Attr_2      Attr_3      Attr_4      Attr_5      Attr_6  \
# count  110.000000  110.000000  110.000000  110.000000  110.000000  110.000000
# mean    67.445455   66.854545   69.490909   70.236364   67.181818   67.209091
# std      7.350449    7.435146    5.953560    7.526013    6.987777    7.440400
# min     32.000000   41.000000   52.000000   34.000000   32.000000   34.000000
# 25%     64.000000   63.000000   66.000000   67.000000   64.000000   64.000000
# 50%     68.000000   67.000000   70.000000   71.500000   68.000000   68.500000
# 75%     72.000000   72.750000   74.000000   75.000000   71.000000   71.000000
# max     80.000000   81.000000   82.000000   84.000000   80.000000   89.000000
#
#            Attr_7      Attr_8      Attr_9     Attr_10  ...     Attr_35  \
# count  110.000000  110.000000  110.000000  110.000000  ...  110.000000
# mean    71.327273   71.218182   63.900000   63.518182  ...   65.400000
# ...

# %%
df.isnull().sum()
# Out:
# Attr_1     0
# Attr_2     0
# Attr_3     0
# Attr_4     0
# Attr_5     0
# Attr_6     0
# Attr_7     0
# Attr_8     0
# Attr_9     0
# Attr_10    0
# Attr_11    0
# Attr_12    0
# Attr_13    0
# Attr_14    0
# Attr_15    0
# Attr_16    0
# Attr_17    0
# Attr_18    0
# Attr_19    0
# Attr_20    0
# Attr_21    0
# Attr_22    0
# Attr_23    0
# Attr_24    0
# Attr_25    0
# Attr_26    0
# Attr_27    0
# Attr_28    0
# Attr_29    0
# Attr_30    0
# Attr_31    0
# Attr_32    0
# Attr_33    0
# Attr_34    0
# Attr_35    0
# Attr_36    0
# Attr_37    0
# Attr_38    0
# Attr_39    0
# Attr_40    0
# Attr_41    0
# Attr_42    0
# Attr_43    0
# Attr_44    0
# Class      0
# dtype: int64

# %%
columns = list(df.columns)
features = columns[:len(columns)-1]
class_labels = list(df[columns[-1]])
dfMod = df[features]

# %%
df['Class'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
pca = PCA(n_components=2)

pComp = pca.fit_transform(dfMod)
principalDf = pd.DataFrame(data = pComp
             , columns = ['PC1', 'PC2'])

# %%
principalDf.head()
# Out:
#          PC1        PC2
# 0 -14.620703  12.190320
# 1  56.576528 -38.863683
# 2   1.770004   8.140100
# 3  51.928467  -0.457349
# 4  -5.882653  18.871547

# %%
plt.figure(figsize=(10,10))                                              
plt.scatter(list(principalDf.iloc[:,0]), list(principalDf.iloc[:,1]), marker='o')       
plt.axis('equal')                                                                 
plt.xlabel('PC1', fontsize=16)                                                 
plt.ylabel('PC2', fontsize=16)                                                 
plt.title('Plot', fontsize=22)                                            
plt.grid()                                                                         
plt.show()

# %%
fcm = FCM(n_clusters=2)
fcm.fit(principalDf)

# %%
fcm_centers = fcm.centers
fcm_labels = fcm.u.argmax(axis=1)

# %%
scatter(pComp[:,0], pComp[:,1])

plt.show()

# %%
scatter(pComp[:,0], pComp[:,1], hue=fcm_labels)
scatter(fcm_centers.iloc[:,0], fcm_centers.iloc[:,1],marker="s",s=200)
plt.show()
